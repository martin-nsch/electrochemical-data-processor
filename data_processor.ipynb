# %%
# %reset -f
import os
import pandas as pd
import numpy as np
# %run ./toolbox.ipynb

# %%
loc=os.getcwd()
files = os.listdir(loc)
results_dic = {}
if 'data' not in files:
    os.mkdir("data")
if 'results' not in files:
    os.mkdir("results")
weight = 0.025

# %%
def weight_calc(sample):
    df = pd.read_excel(loc+"\\weight.xlsx")
    if ('ine' in sample):
        if ('naced' in sample):
            af = df[df.eq("Furnaced").any(axis=1)]
            weight = float(af['weight'].values)
        else:    
            af = df[df.eq("Pristine").any(axis=1)]
            weight = float(af['weight'].values)

    elif (('cid' in sample) and ('naced' in sample)):
        if (('60') in sample):
            af = df[df.eq("Acid Etched 60min Furnaced").any(axis=1)]
            weight = float(af['weight'].values)
        elif ('45' in sample):
            af = df[df.eq("Acid Etched 45min Furnaced").any(axis=1)]
            weight = float(af['weight'].values)
        elif ('30' in sample):
            af = df[df.eq("Acid Etched 30min Furnaced").any(axis=1)]
            weight = float(af['weight'].values)
        elif('15' in sample):
            af = df[df.eq("Acid Etched 15min Furnaced").any(axis=1)]
            weight = float(af['weight'].values)
            
    elif ('naced' in sample):
        af = df[df.eq("Furnaced").any(axis=1)]
        weight = float(af['weight'].values)

    elif ('cid' in sample):
        if ('60' in sample):
            af = df[df.eq("Acid Etched 60min").any(axis=1)]
            weight = float(af['weight'].values)
        elif ('45' in sample):
            af = df[df.eq("Acid Etched 45min").any(axis=1)]
            weight = float(af['weight'].values)
        elif ('30' in sample):
            af = df[df.eq("Acid Etched 30min").any(axis=1)]
            weight = float(af['weight'].values)
        elif('15' in sample):
            af = df[df.eq("Acid Etched 15min").any(axis=1)]
            weight = float(af['weight'].values)
    else:
        weight = 0
    return(weight)

# %%
ace = np.zeros(3)
for i in range(len(files)):
    if ((('cid') in files[i]) or (('ase') in files[i]) or (('naced') in files[i]) or (('tine') in files[i])):
        print(files[i])
        first_PEIS(loc+'\\'+files[i],files[i])
        sol2 = PCGA(loc+'\\'+files[i],files[i])
        sol3 = ECSA_calc(loc+'\\'+files[i],files[i])
        sol1 = second_PEIS(loc+'\\'+files[i],files[i])
        weight = weight_calc(files[i])
        print(weight)
        results_dic = {'Sample':files[i],
            'R_PEIS/Ohm':sol1[0],
            'Electrode/Ohm':sol1[1],
            'Electrolyte/Ohm':sol1[2],
            'Mass_transfer/Ohm':sol1[3],
            'R_PCGA/Ohm':sol2[0],
            'ECSA(m^2)':sol3,
            'Specific ECSA (m^2/g)':sol3/weight
         }
        if type(sol2[1]) != type(int(3)):
            sol2[1].to_excel('./data/'+files[i]+'_PCGA.xlsx',index=None)
        results_df = pd.DataFrame(results_dic, index=[0])
        results_df.to_excel('./data/'+files[i]+'_results.xlsx',index=None)
# Out:
# Acid etched 60min 1
# PERF_AE1_Experiment 3_01_PEIS_C07.txt
# PERF_AE1_Experiment 3_02_PCGA_C07.txt
# CV_AE1_Experiment 3_02_CV_C07.txt
# CV_AE1_Experiment 3_03_CV_C07.txt
# CV_AE1_Experiment 3_04_CV_C07.txt
# CV_AE1_Experiment 3_05_CV_C07.txt
# CV_AE1_Experiment 3_06_CV_C07.txt
# CV_AE1_Experiment 3_07_CV_C07.txt
# PERF_AE1_Experiment 3_03_PEIS_C07.txt
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:18: RankWarning: Polyfit may be poorly conditioned
#   pars = np.polyfit(PEIS_02['Re(Z)/Ohm'],PEIS_02['-Im(Z)/Ohm'],25)
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:28: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   electrolyte_res = float(PEIS_02['Re(Z)/Ohm'].iloc[[min2[0][0]]])
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mass_res_df = PEIS_02.drop(PEIS_02[ PEIS_02['Re(Z)/Ohm'] < float(PEIS_02['Re(Z)/Ohm'].iloc[[min2[0][0]]])].index)
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mass_res_df = mass_res_df.drop(mass_res_df[ mass_res_df['Re(Z)/Ohm'] < float(mass_res_df['Re(Z)/Ohm'].iloc[[np.argmax(mass_res_df["-Im(Z)/Ohm"])]])].index)
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:38: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mass_resistance = float(mass_res)
# 0.0247
# Pristine 1
# N_F0_impedence_01_PEIS_C07.txt
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3121587540.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   weight = float(af['weight'].values)
# N_F0_polarization_1m_C05.txt
# N_F0_capacitance_02_CV_C07.txt
# N_F0_capacitance_03_CV_C07.txt
# N_F0_capacitance_04_CV_C07.txt
# N_F0_capacitance_05_CV_C07.txt
# N_F0_capacitance_06_CV_C07.txt
# N_F0_capacitance_07_CV_C07.txt
# N_F0_impedence_02_PEIS_C07.txt
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:18: RankWarning: Polyfit may be poorly conditioned
#   pars = np.polyfit(PEIS_02['Re(Z)/Ohm'],PEIS_02['-Im(Z)/Ohm'],25)
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:28: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   electrolyte_res = float(PEIS_02['Re(Z)/Ohm'].iloc[[min2[0][0]]])
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mass_res_df = PEIS_02.drop(PEIS_02[ PEIS_02['Re(Z)/Ohm'] < float(PEIS_02['Re(Z)/Ohm'].iloc[[min2[0][0]]])].index)
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mass_res_df = mass_res_df.drop(mass_res_df[ mass_res_df['Re(Z)/Ohm'] < float(mass_res_df['Re(Z)/Ohm'].iloc[[np.argmax(mass_res_df["-Im(Z)/Ohm"])]])].index)
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3714298298.py:38: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mass_resistance = float(mass_res)
# 0.0259
# C:\Users\marti\AppData\Local\Temp\ipykernel_16000\3121587540.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   weight = float(af['weight'].values)
